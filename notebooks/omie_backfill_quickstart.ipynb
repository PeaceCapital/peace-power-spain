# %% [markdown]
# # OMIE Backfill Quickstart
#
# Use this notebook to pull a real OMIE history block into pandas and save it locally for model work.

# %%
from pathlib import Path

from peace_power import fetch_omie_history

# %%
omie = fetch_omie_history(
    "2024-01-01",
    "2025-12-31",
    output_dir="../data/raw/omie",
)
omie.head()

# %%
omie.tail()

# %%
omie[["datetime", "price_omie"]].describe(include="all")

# %%
target = Path("../data/raw/omie/omie_history.csv")
target.parent.mkdir(parents=True, exist_ok=True)
omie.to_csv(target, index=False)
target
