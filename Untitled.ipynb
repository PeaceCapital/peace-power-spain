# %%
from peace_power import fetch_omie_marginal_prices, search_esios_indicators
# Out:
# /Users/oly/Documents/New project/peace-power-spain/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
python3 -m pip install jupyterlab ipykernel
jupyter lab
# Out:
#   Cell In[2], line 1
#     python3 -m pip install jupyterlab ipykernel
#                ^
# SyntaxError: invalid syntax

# %%
from peace_power import fetch_omie_marginal_prices, search_esios_indicators

# %%
from peace_power import fetch_omie_marginal_prices, search_esios_indicators

omie = fetch_omie_marginal_prices(
    "2026-03-01",
    "2026-03-07",
    output_dir="../data/raw/omie",
)
omie.head()
# Out:
#              datetime delivery_date  period  period_minutes  price_portugal  \
# 0 2026-03-01 00:00:00    2026-03-01       1              15           35.01
# 1 2026-03-01 00:15:00    2026-03-01       2              15           35.01
# 2 2026-03-01 00:30:00    2026-03-01       3              15           35.00
# 3 2026-03-01 00:45:00    2026-03-01       4              15           24.84
# 4 2026-03-01 01:00:00    2026-03-01       5              15           27.25
#
#    price_spain  price_omie              source_file  omie_revision
# 0        35.01       35.01  marginalpdbc_20260301.1              1
# 1        35.01       35.01  marginalpdbc_20260301.1              1
# 2        35.00       35.00  marginalpdbc_20260301.1              1
# 3        24.84       24.84  marginalpdbc_20260301.1              1
# 4        27.25       27.25  marginalpdbc_20260301.1              1

# %%
ESIOS_TOKEN = "ESIOS_TOKEN"

matches = search_esios_indicators("bateria", token=ESIOS_TOKEN)
matches[["id", "name", "short_name"]].head(10)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Documents/New project/peace-power-spain/src/peace_power/io.py:41, in _raise_for_status(response)
#      40 try:
# ---> 41     response.raise_for_status()
#      42 except requests.HTTPError as exc:
#
# File ~/Documents/New project/peace-power-spain/.venv/lib/python3.9/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.esios.ree.es/search?query=bateria
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 ESIOS_TOKEN = "ESIOS_TOKEN"
# ----> 3 matches = search_esios_indicators("bateria", token=ESIOS_TOKEN)
# ...

# %%
from peace_power import search_esios_indicators

ESIOS_TOKEN = "YOUR_REAL_TOKEN"
matches = search_esios_indicators("bateria", token=ESIOS_TOKEN)
matches[["id", "name", "short_name"]].head(10)
# Out:
# /Users/oly/Documents/New project/peace-power-spain/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Documents/New project/peace-power-spain/src/peace_power/io.py:41, in _raise_for_status(response)
#      40 try:
# ---> 41     response.raise_for_status()
#      42 except requests.HTTPError as exc:
#
# File ~/Documents/New project/peace-power-spain/.venv/lib/python3.9/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# ...

# %%
import requests

headers = {
    "Accept": "application/json; application/vnd.esios-api-v1+json",
    "Content-Type": "application/json",
    "x-api-key": ESIOS_TOKEN.strip(),
}
r = requests.get(
    "https://api.esios.ree.es/indicators",
    headers=headers,
    params={"text": "bateria"},
    timeout=30,
)
print(r.status_code)
print(r.text[:300])
# Out:
# 403
# {"Status":403,"message":"Forbidden"}

# %%
from peace_power import search_esios_indicators
matches = search_esios_indicators("bateria", token="YOUR_REAL_TOKEN")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Documents/New project/peace-power-spain/src/peace_power/io.py:41, in _raise_for_status(response)
#      40 try:
# ---> 41     response.raise_for_status()
#      42 except requests.HTTPError as exc:
#
# File ~/Documents/New project/peace-power-spain/.venv/lib/python3.9/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.esios.ree.es/indicators?text=bateria
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 from peace_power import search_esios_indicators
# ...

# %%
token = "YOUR_REAL_ESIOS_TOKEN".strip()
print(len(token), token[:8])
# Out:
# 21 YOUR_REA

# %%
import requests

headers = {
    "Accept": "application/json; application/vnd.esios-api-v1+json",
    "Content-Type": "application/json",
    "x-api-key": token,
}
r = requests.get(
    "https://api.esios.ree.es/indicators",
    headers=headers,
    params={"text": "bateria"},
    timeout=30,
)
print(r.status_code)
print(r.text[:300])
# Out:
# 403
# {"Status":403,"message":"Forbidden"}

# %%
from peace_power import fetch_omie_history

omie = fetch_omie_history(
    "2024-01-01",
    "2025-12-31",
    output_dir="../data/raw/omie",
)
omie.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from peace_power import fetch_omie_history
#       3 omie = fetch_omie_history(
#       4     "2024-01-01",
#       5     "2025-12-31",
#       6     output_dir="../data/raw/omie",
#       7 )
#       8 omie.head()
#
# ImportError: cannot import name 'fetch_omie_history' from 'peace_power' (/Users/oly/Documents/New project/peace-power-spain/src/peace_power/__init__.py)

# %%
from peace_power import fetch_omie_history

omie = fetch_omie_history(
    "2024-01-01",
    "2025-12-31",
    output_dir="../data/raw/omie",
)
omie.head()
# Out:
# /Users/oly/Documents/New project/peace-power-spain/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Documents/New project/peace-power-spain/src/peace_power/io.py:42, in _raise_for_status(response)
#      41 try:
# ---> 42     response.raise_for_status()
#      43 except requests.HTTPError as exc:
#
# File ~/Documents/New project/peace-power-spain/.venv/lib/python3.9/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# ...

# %%
import importlib
import peace_power

print(peace_power.__file__)
importlib.reload(peace_power)
print("fetch_omie_history" in dir(peace_power))
# Out:
# /Users/oly/Documents/New project/peace-power-spain/src/peace_power/__init__.py
# True

# %%
from peace_power import fetch_omie_history

omie = fetch_omie_history(
    "2024-01-01",
    "2025-12-31",
    output_dir="../data/raw/omie",
)
omie.head()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/Documents/New project/peace-power-spain/.venv/lib/python3.9/site-packages/urllib3/connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File ~/Documents/New project/peace-power-spain/.venv/lib/python3.9/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
# ...
